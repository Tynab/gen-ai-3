# %%
import os

from dotenv import load_dotenv
from langchain_openai import ChatOpenAI

# %%
load_dotenv()

# Model lấy từ .env (OPENAI_MODEL), không hardcode trong code.
# Lưu ý: họ gpt-5 chỉ chấp nhận temperature = 1. Không thể "bỏ trống" tham số này,
# vì langchain-openai 0.0.2 luôn gửi kèm temperature mặc định 0.7 -> API trả 400.
llm = ChatOpenAI(
    model=os.getenv("OPENAI_MODEL"),
    temperature=1,
    api_key=os.getenv("OPENAI_API_KEY")
)

# %%
messages = [
    ("system", "Bạn là một trợ lý AI, bạn sẽ trả lời bằng tiếng Việt"),
    ("human", "Python là gì?")
]

# %%
result = llm.invoke(messages)

result
# Out:
# AIMessage(content='Python là một ngôn ngữ lập trình bậc cao, thông dịch, đa dụng và dễ đọc, được Guido van Rossum tạo ra và phát hành lần đầu năm 1991.\n\nCác điểm chính:\n- Thiết kế hướng tới sự đơn giản và dễ đọc: cú pháp rõ ràng, ít dấu ngoặc; phù hợp cho người mới học lẫn lập trình viên chuyên nghiệp.\n- Đặc tính: thông dịch (không cần biên dịch trước), gõ động (dynamic typing), quản lý bộ nhớ tự động (garbage collection).\n- Hỗ trợ nhiều mô hình lập trình: thủ tục, hướng đối tượng, chức năng.\n- Nhiều thư viện và cộng đồng lớn: có sẵn hàng chục nghìn package (cài bằng pip) cho web, khoa học dữ liệu, học máy, tự động hoá, mạng, v.v.\n- Các triển khai phổ biến: CPython (chuẩn), PyPy (JIT), Jython (trên JVM), IronPython (trên .NET).\n- Phiên bản: Python 3 là dòng hiện đại (Python 2 đã kết thúc hỗ trợ năm 2020).\n\nVí dụ đơn giản:\nprint("Hello, world!")\n# hàm\ndef tong(a, b):\n    return a + b\n\nỨng dụng tiêu biểu:\n- Web: Django, Flask, FastAPI\n- Khoa học dữ liệu & ML: NumPy, p
# ...

# %%
result.content
# Out:
# 'Python là một ngôn ngữ lập trình bậc cao, thông dịch, đa dụng và dễ đọc, được Guido van Rossum tạo ra và phát hành lần đầu năm 1991.\n\nCác điểm chính:\n- Thiết kế hướng tới sự đơn giản và dễ đọc: cú pháp rõ ràng, ít dấu ngoặc; phù hợp cho người mới học lẫn lập trình viên chuyên nghiệp.\n- Đặc tính: thông dịch (không cần biên dịch trước), gõ động (dynamic typing), quản lý bộ nhớ tự động (garbage collection).\n- Hỗ trợ nhiều mô hình lập trình: thủ tục, hướng đối tượng, chức năng.\n- Nhiều thư viện và cộng đồng lớn: có sẵn hàng chục nghìn package (cài bằng pip) cho web, khoa học dữ liệu, học máy, tự động hoá, mạng, v.v.\n- Các triển khai phổ biến: CPython (chuẩn), PyPy (JIT), Jython (trên JVM), IronPython (trên .NET).\n- Phiên bản: Python 3 là dòng hiện đại (Python 2 đã kết thúc hỗ trợ năm 2020).\n\nVí dụ đơn giản:\nprint("Hello, world!")\n# hàm\ndef tong(a, b):\n    return a + b\n\nỨng dụng tiêu biểu:\n- Web: Django, Flask, FastAPI\n- Khoa học dữ liệu & ML: NumPy, pandas, scikit-lear
# ...

# %%
from langchain_core.prompts import ChatPromptTemplate

messages = [
    ("system", "Bạn là một trợ lý AI, bạn sẽ trả lời bằng {language}"),
    ("human", "{input}")
]

prompt = ChatPromptTemplate.from_messages(messages)

# %%
chain = prompt | llm

# %%
result = chain.invoke({
    "language": "Bồ Đào Nha",
    "input": "Python là gì?"
})

result.content
# Out:
# 'Python é uma linguagem de programação de alto nível, interpretada e de propósito geral, criada por Guido van Rossum e lançada em 1991. É projetada para ser simples e legível, com sintaxe clara que facilita aprendizado e manutenção de código.\n\nPrincipais características\n- Sintaxe legível e concisa.\n- Tipagem dinâmica e gerenciamento automático de memória (garbage collection).\n- Suporte a múltiplos paradigmas: procedural, orientado a objetos e funcional.\n- Grande biblioteca padrão e ecossistema de pacotes (PyPI).\n- Implementações populares: CPython (referência), PyPy, Jython, IronPython.\n\nPrincipais usos\n- Desenvolvimento web (Django, Flask).\n- Ciência de dados e análise (NumPy, pandas).\n- Machine learning e IA (scikit-learn, TensorFlow, PyTorch).\n- Automação e scripting.\n- Ferramentas de linha de comando, DevOps.\n- Aplicações desktop e prototipagem.\n\nExemplo simples (Python 3)\n- Hello world:\n  print("Olá, mundo!")\n- Função:\n  def soma(a, b):\n      return a + b\n
# ...
